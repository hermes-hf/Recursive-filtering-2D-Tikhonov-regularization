# %%
using Pkg
using Plots
using Statistics
using LinearAlgebra
using ForwardDiff
import PyPlot as py
using FFTW
using SpecialFunctions
using ColorSchemes
using PyCall
using DelimitedFiles
using Images
using SparseArrays
using BenchmarkTools
using DelimitedFiles
using JLD
include("..//source//tikhonov2d_iterative.jl");
include("..//source//dericheFilter.jl");

# %% [markdown]
# # Instructions

# %% [markdown]
# User should execute homogeneous_error_threaded.jl to obtain the err.jl files used for analysis

# %% [markdown]
# # Frequency Plots

# %%
lx = 80
ly = 30

t = zeros(100)
for i =0:99
    t[i+1] = Jfun(lx,ly,pi*i/100)
end


t = zeros(100)
for i =1:100
    t[i] = Jfun(lx,ly,pi*i/100)
end

py.plot(t, label ="exact")
py.plot(gaussianKernelFitPlot(lx, ly, 6; linOpt=1), label="fitted")
py.legend()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x000000005769CE50>

# %% [markdown]
# # Routine to filter RGB image with FFT

# %%
function fftfilter2D(img,lx,ly)
    channels, N, M = size(img)
    N2 = 2*N; #increase image size to avoid circular filtering
    M2 = 2*M
    
    g = zeros(ComplexF64, channels, N2, M2)
    g[:,1:N,1:M] = img #embbed image
    
    g = fft(g)
    for i =1:N2, j=1:M2
        w = 2*pi*(i-1)/N2
        xi = 2*pi*(j-1)/M2
        g[:,i,j] = g[:,i,j]/(1+2*lx*(1-cos(w))+2*ly*(1-cos(xi)))
    end
    
    return clamp01.(real.(ifft(g)))[:,1:N,1:M] #clamp values in [0,1]
end;

# %% [markdown]
# # Impulse Response

# %%
@time begin 
    A, Sx, Sy, c0  =  gaussianKernelFit(1,100,7; linOpt = 0);
    improve(A,Sx,Sy,c0,1,100); #apply non-linear improvement
end;
# Out:
#   0.101489 seconds (2.60 k allocations: 75.297 KiB)

# %%
N = 100
p = N÷2
L = N
nGaussian =5
img = zeros(1,N,N)
img[1,p, p] = 1
lx = 70
ly = 40
fftRes = fftfilter2D(img,lx,ly)[1,1:L,1:L];
dericheRes =  recursiveFilter2D(img,lx,ly, nGaussian)[1,1:L,1:L];
dericheRes =  recursiveFilter2Doptimize(img,lx,ly, nGaussian)[1,1:L,1:L]

@show assess_psnr(fftRes,dericheRes,1)
@show norm(fftRes-dericheRes)/norm(fftRes)
@show norm(fftRes-dericheRes,1)/norm(fftRes,1)

#plot(dericheRes[p,:], label = "deriche")
#plot!(fftRes[p,:], label="fft")

plot(dericheRes[p,:] .+ 1e-6, yscale = :log10, label = "deriche")
plot!(fftRes[p,:] .+ 1e-6, label="fft")
# Out:
# assess_psnr(fftRes, dericheRes, 1) = 104.64693113018569
# norm(fftRes - dericheRes) / norm(fftRes) = 0.015005404888169998
# norm(fftRes - dericheRes, 1) / norm(fftRes, 1) = 0.015163302729180785

# %%
norm(dericheRes[:,p] - fftRes[:,p])/norm(fftRes[:,p])
# Out:
# 0.0020351077628774283

# %%
imresize(
colorview(Gray,imadjustintensity(abs.(fftRes-dericheRes))), ratio=4.0)
# Out:
# 400×400 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.000321058)  …  Gray{Float64}(0.000281142)
#  Gray{Float64}(0.000321058)     Gray{Float64}(0.000281142)
#  Gray{Float64}(0.000324163)     Gray{Float64}(0.000283835)
#  Gray{Float64}(0.000330375)     Gray{Float64}(0.000289221)
#  Gray{Float64}(0.000336586)     Gray{Float64}(0.000294607)
#  Gray{Float64}(0.000342797)  …  Gray{Float64}(0.000299992)
#  Gray{Float64}(0.000349192)     Gray{Float64}(0.000305536)
#  Gray{Float64}(0.000355772)     Gray{Float64}(0.000311236)
#  Gray{Float64}(0.000362351)     Gray{Float64}(0.000316937)
#  Gray{Float64}(0.00036893)      Gray{Float64}(0.000322638)
#  Gray{Float64}(0.000375698)  …  Gray{Float64}(0.0003285)
#  Gray{Float64}(0.000382655)     Gray{Float64}(0.000334523)
#  Gray{Float64}(0.000389612)     Gray{Float64}(0.000340546)
#  ⋮                           ⋱
#  Gray{Float64}(0.000355772)     Gray{Float64}(0.000311236)
#  Gray{Float64}(0.000349192)     Gray{Float64}(0.000305536)
#  Gray{Float64}(0.000342797)  …  Gray{Float64}(0.000299992)
#  Gray{Float64}(0.000336586)     Gray{Float64}(0.000294607)
#  Gray{Float64}(0.000330375)     Gray{Float64}(0.000289221)
#  Gray{Float64}(0.000324163)     Gray{Float64}(0.000283835)
#  Gray{Float64}(0.000318131)     Gray{Float64}(0.000278603)
#  Gray{Float64}(0.000312278)  …  Gray{Float64}(0.000273523)
#  Gray{Float64}(0.000306425)     Gray{Float64}(0.000268444)
#  Gray{Float64}(0.000300571)     Gray{Float64}(0.000263365)
#  Gray{Float64}(0.000297644)     Gray{Float64}(0.000260825)
#  Gray{Float64}(0.000297644)     Gray{Float64}(0.000260825)

# %% [markdown]
# # Single Image Comparison

# %%
lx = 1000;
ly = 1000;
nGaussian =5;

img = load("../data/kodak7.jpg") .|>RGB{Float64}  |>channelview

fftFiltered = fftfilter2D(img,lx,ly)

@time gaussianFiltered = 
        recursiveFilter2D(img, lx,ly, nGaussian, linOpt=1)

im1 = colorview(RGB, fftFiltered)
im2 = colorview(RGB, gaussianFiltered);

print("rel error: ",norm(fftFiltered .- gaussianFiltered)/norm(fftFiltered),"\n")
print("psnr: ",assess_psnr(fftFiltered,gaussianFiltered,1),"\n")
print("extrema", extrema(fftFiltered-gaussianFiltered).*255, "\n")
colorview(RGB,hcat(im1,im2))
# Out:
#   3.656224 seconds (494.56 k allocations: 3.201 GiB, 10.44% gc time)
# rel error: 0.011946319203765626
# psnr: 46.46650560319835
# extrema(-0.38793092415266933, 2.3300491586821215)
# 768×2304 Array{RGB{Float64},2} with eltype RGB{Float64}:
#  RGB{Float64}(0.119554,0.119549,0.107629)     …  RGB{Float64}(0.114935,0.107816,0.0759143)
#  RGB{Float64}(0.123184,0.123178,0.110931)        RGB{Float64}(0.118504,0.111289,0.0785176)
#  RGB{Float64}(0.126704,0.126697,0.11412)         RGB{Float64}(0.121974,0.114662,0.0810146)
#  RGB{Float64}(0.130129,0.13012,0.117215)         RGB{Float64}(0.12534,0.117929,0.0834084)
#  RGB{Float64}(0.133463,0.133452,0.120218)        RGB{Float64}(0.128618,0.121108,0.0857191)
#  RGB{Float64}(0.1367,0.136685,0.123121)       …  RGB{Float64}(0.131825,0.124214,0.0879679)
#  RGB{Float64}(0.139856,0.139839,0.125942)        RGB{Float64}(0.134949,0.127235,0.0901488)
#  RGB{Float64}(0.142923,0.142903,0.128675)        RGB{Float64}(0.137997,0.130177,0.0922702)
#  RGB{Float64}(0.145905,0.145883,0.131324)        RGB{Float64}(0.140961,0.133034,0.094329)
#  RGB{Float64}(0.148802,0.14878,0.133892)         RGB{Float64}(0.143841,0.135805,0.0963215)
#  RGB{Float64}(0.151617,0.151594,0.136381)     …  RGB{Float64}(0.146637,0.138492,0.0982458)
#  RGB{Float64}(0.154351,0.154327,0.138794)        RGB{Float64}(0.14935,0.141097,0.100106)
#  RGB{Float64}(0.157007,0.156981,0.141133)        RGB{Float64}(0.151981,0.143621,0.101904)
#  ⋮                                            ⋱
#  RGB{Float64}(0.120095,0.109114,0.0740821)       RGB{Float64}(0.136559,0.134812,0.0921169)
#  RGB{Float64}(0.117817,0.107046,0.0727462)       RGB{Float64}(0.133978,0.132198,0.0904961)
#  RGB{Float64}(0.115462,0.104908,0.0713329)       RGB{Float64}(0.131284,0.12948,0.088783)
#  RGB{Float64}(0.113028,0.102696,0.0698428)       RGB{Float64}(0.128483,0.126661,0.0869774)
#  RGB{Float64}(0.110512,0.100406,0.0682715)    …  RGB{Float64}(0.125583,0.12375,0.0850881)
#  RGB{Float64}(0.107908,0.0980336,0.0666189)      RGB{Float64}(0.122583,0.120748,0.0831093)
#  RGB{Float64}(0.105213,0.0955751,0.0648799)      RGB{Float64}(0.119482,0.117654,0.0810327)
#  RGB{Float64}(0.102421,0.0930277,0.0630483)      RGB{Float64}(0.116274,0.114462,0.0788462)
#  RGB{Float64}(0.0995253,0.0903834,0.0611157)     RGB{Float64}(0.112937,0.111147,0.0765258)
#  RGB{Float64}(0.0965145,0.0876233,0.0590603)  …  RGB{Float64}(0.109475,0.107711,0.0740739)
#  RGB{Float64}(0.0933653,0.0847232,0.0568567)     RGB{Float64}(0.10588,0.104147,0.071488)
#  RGB{Float64}(0.0903622,0.081967,0.0547826)      RGB{Float64}(0.102404,0.100702,0.0690118)

# %%
save("../output/compareFFT_100_40.png",colorview(RGB,hcat(im1,im2)))

# %%
colorview(Gray,imadjustintensity(fftFiltered-gaussianFiltered)[1,:,:])
# Out:
# 768×1152 reinterpret(reshape, Gray{Float64}, ::Matrix{Float64}) with eltype Gray{Float64}:
#  Gray{Float64}(0.781076)  Gray{Float64}(0.739093)  …  Gray{Float64}(0.775058)
#  Gray{Float64}(0.740918)  Gray{Float64}(0.67076)      Gray{Float64}(0.732845)
#  Gray{Float64}(0.717574)  Gray{Float64}(0.637678)     Gray{Float64}(0.708803)
#  Gray{Float64}(0.705015)  Gray{Float64}(0.622404)     Gray{Float64}(0.695063)
#  Gray{Float64}(0.69839)   Gray{Float64}(0.615437)     Gray{Float64}(0.68634)
#  Gray{Float64}(0.692273)  Gray{Float64}(0.607247)  …  Gray{Float64}(0.680452)
#  Gray{Float64}(0.690839)  Gray{Float64}(0.606191)     Gray{Float64}(0.67685)
#  Gray{Float64}(0.689029)  Gray{Float64}(0.604025)     Gray{Float64}(0.675625)
#  Gray{Float64}(0.688427)  Gray{Float64}(0.60313)      Gray{Float64}(0.673244)
#  Gray{Float64}(0.686488)  Gray{Float64}(0.601177)     Gray{Float64}(0.670379)
#  Gray{Float64}(0.684703)  Gray{Float64}(0.59884)   …  Gray{Float64}(0.66737)
#  Gray{Float64}(0.684396)  Gray{Float64}(0.598426)     Gray{Float64}(0.665753)
#  Gray{Float64}(0.685835)  Gray{Float64}(0.599569)     Gray{Float64}(0.665612)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.669177)  Gray{Float64}(0.583304)     Gray{Float64}(0.680308)
#  Gray{Float64}(0.671975)  Gray{Float64}(0.586465)     Gray{Float64}(0.680062)
#  Gray{Float64}(0.674106)  Gray{Float64}(0.58834)      Gray{Float64}(0.681063)
#  Gray{Float64}(0.67597)   Gray{Float64}(0.5901)       Gray{Float64}(0.682797)
#  Gray{Float64}(0.67963)   Gray{Float64}(0.59367)   …  Gray{Float64}(0.686068)
#  Gray{Float64}(0.685079)  Gray{Float64}(0.599976)     Gray{Float64}(0.694323)
#  Gray{Float64}(0.693078)  Gray{Float64}(0.609042)     Gray{Float64}(0.706406)
#  Gray{Float64}(0.706233)  Gray{Float64}(0.625504)     Gray{Float64}(0.721748)
#  Gray{Float64}(0.729371)  Gray{Float64}(0.658416)     Gray{Float64}(0.748564)
#  Gray{Float64}(0.770485)  Gray{Float64}(0.727913)  …  Gray{Float64}(0.78953)
#  Gray{Float64}(0.771129)  Gray{Float64}(0.729248)     Gray{Float64}(0.790241)
#  Gray{Float64}(0.81262)   Gray{Float64}(0.798809)     Gray{Float64}(0.830619)

# %% [markdown]
# # Multiple image comparison

# %% [markdown]
# # Using Optimizer

# %%
#Exact kernel from ift
function extractKernel2d(lx,ly,n,N)
    g = zeros(ComplexF64,n,n)
    for i =1:n, j=1:n
        w = 2*pi*(i-1)/n
        xi = 2*pi*(j-1)/n
        g[i,j] = 1/(1+2*lx*(1-cos(w))+2*ly*(1-cos(xi)))#*exp(im*w)*exp(im*xi)
    end
     g = real.(FFTW.ifft(g))
    return g[1:N,1:N]
end;

# %%
lx = 200
ly = 200
ng = 10
@time begin
    A, Sx, Sy, c0 = gaussianKernelFit(lx, ly, ng; linOpt=0)
    A, Sx, Sy, c0 = improve(A, Sx, Sy, c0,10,10)
end;
# Out:
#   0.261601 seconds (1.05 k allocations: 55.656 KiB, 14.72% compilation time)

# %% [markdown]
# ## Single image

# %%
lx = 100
ly = 100
nGaussian = 6;

img = load("../data/kodak7.jpg") |>channelview

fftFiltered = fftfilter2D(img,lx,ly)
@time gaussianFiltered = recursiveFilter2Doptimize(img, lx,ly, nGaussian)
im1 = colorview(RGB, fftFiltered)
im2 = colorview(RGB, gaussianFiltered);

@show assess_psnr(fftFiltered,gaussianFiltered,1)

colorview(RGB,hcat(im1,im2))
# Out:
#   6.820182 seconds (593.33 k allocations: 3.033 GiB, 13.51% gc time)
# assess_psnr(fftFiltered, gaussianFiltered, 1) = 57.82182337832015
# 768×2304 Array{RGB{Float64},2} with eltype RGB{Float64}:
#  RGB{Float64}(0.117946,0.118179,0.111679)     …  RGB{Float64}(0.113725,0.117647,0.0980392)
#  RGB{Float64}(0.128358,0.128601,0.121589)        RGB{Float64}(0.12549,0.129412,0.105882)
#  RGB{Float64}(0.137724,0.137973,0.130454)        RGB{Float64}(0.137255,0.137255,0.113725)
#  RGB{Float64}(0.146271,0.146525,0.138507)        RGB{Float64}(0.145098,0.145098,0.121569)
#  RGB{Float64}(0.154082,0.154338,0.145843)        RGB{Float64}(0.152941,0.152941,0.129412)
#  RGB{Float64}(0.161137,0.161393,0.152398)     …  RGB{Float64}(0.160784,0.160784,0.133333)
#  RGB{Float64}(0.167653,0.167911,0.158405)        RGB{Float64}(0.168627,0.168627,0.137255)
#  RGB{Float64}(0.173582,0.17385,0.163832)         RGB{Float64}(0.172549,0.176471,0.145098)
#  RGB{Float64}(0.178989,0.179277,0.168751)        RGB{Float64}(0.180392,0.180392,0.14902)
#  RGB{Float64}(0.183912,0.184231,0.173205)        RGB{Float64}(0.184314,0.188235,0.152941)
#  RGB{Float64}(0.188392,0.188748,0.177239)     …  RGB{Float64}(0.188235,0.192157,0.156863)
#  RGB{Float64}(0.192469,0.192864,0.180895)        RGB{Float64}(0.192157,0.196078,0.160784)
#  RGB{Float64}(0.196182,0.196613,0.184211)        RGB{Float64}(0.2,0.2,0.164706)
#  ⋮                                            ⋱
#  RGB{Float64}(0.165995,0.155533,0.136812)        RGB{Float64}(0.192157,0.188235,0.14902)
#  RGB{Float64}(0.161815,0.151668,0.133767)        RGB{Float64}(0.184314,0.184314,0.145098)
#  RGB{Float64}(0.157193,0.14738,0.130256)         RGB{Float64}(0.180392,0.176471,0.141176)
#  RGB{Float64}(0.152083,0.14262,0.126275)         RGB{Float64}(0.176471,0.172549,0.137255)
#  RGB{Float64}(0.146433,0.137324,0.12176)      …  RGB{Float64}(0.168627,0.164706,0.133333)
#  RGB{Float64}(0.140156,0.131438,0.116693)        RGB{Float64}(0.160784,0.156863,0.129412)
#  RGB{Float64}(0.1332,0.124889,0.110999)          RGB{Float64}(0.152941,0.14902,0.121569)
#  RGB{Float64}(0.125458,0.117617,0.104587)        RGB{Float64}(0.145098,0.141176,0.117647)
#  RGB{Float64}(0.116822,0.109504,0.0973388)       RGB{Float64}(0.137255,0.133333,0.109804)
#  RGB{Float64}(0.107123,0.100315,0.0889965)    …  RGB{Float64}(0.12549,0.121569,0.0980392)
#  RGB{Float64}(0.096069,0.0897537,0.0792561)      RGB{Float64}(0.113725,0.109804,0.0901961)
#  RGB{Float64}(0.0864352,0.0805925,0.0708337)     RGB{Float64}(0.101961,0.0980392,0.0823529)

# %%
# Relative error:
norm(fftFiltered .- gaussianFiltered)/norm(fftFiltered)
# Out:
# 0.0030434125124084934

# %% [markdown]
# # Compute (ly,lx) pairs for analysis

# %%
#err2 = load("err2.jld","data");
err1 = load("..\\homog_error\\err1.jld","data");
err2 = load("..\\homog_error\\err2.jld","data");
psnr = load("..\\homog_error\\psnr.jld","data");

ierr1 = load("..\\homog_error\\improv_err1.jld","data");
ierr2 = load("..\\homog_error\\improv_err2.jld","data");
ipsnr = load("..\\homog_error\\improv_psnr.jld","data");

# %%
py.imshow(minimum(psnr; dims=4)[2,:,:], cmap=:CMRmap);
py.colorbar()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x000000006F7D2D30>

# %% [markdown]
# # Linear optimized

# %%
gaussian_4_mean_psnr = mean(psnr[1,:,:,:])
gaussian_4_std_psnr = std(psnr[1,:,:,:])
gaussian_4_min_psnr = minimum(psnr[1,:,:,:])

print("mean psnr = ", gaussian_4_mean_psnr,"\n")
print("std psnr = ", gaussian_4_std_psnr, "\n")
print("minimum psnr = ", gaussian_4_min_psnr)
# Out:
# mean psnr = 47.185330497813034
# std psnr = 3.1341894211144554
# minimum psnr = 38.098462956380835

# %%
gaussian_5_mean_psnr = mean(psnr[2,:,:,:])
gaussian_5_std_psnr = std(psnr[2,:,:,:])
gaussian_5_min_psnr = minimum(psnr[2,:,:,:])

print("mean psnr = ", gaussian_5_mean_psnr,"\n")
print("std psnr = ", gaussian_5_std_psnr, "\n")
print("minimum psnr = ", gaussian_5_min_psnr)
# Out:
# mean psnr = 53.179117521882034
# std psnr = 4.154367285007478
# minimum psnr = 42.06230572565559

# %%
gaussian_6_mean_psnr = mean(psnr[3,:,:,:])
gaussian_6_std_psnr = std(psnr[3,:,:,:])
gaussian_6_min_psnr = minimum(psnr[3,:,:,:])

print("mean psnr = ", gaussian_6_mean_psnr,"\n")
print("std psnr = ", gaussian_6_std_psnr, "\n")
print("minimum psnr = ", gaussian_6_min_psnr)
# Out:
# mean psnr = 45.631252687444345
# std psnr = 3.4605917264763595
# minimum psnr = 40.6773422248948

# %% [markdown]
# # Non linear optimized

# %%
gaussian_4_mean_psnr = mean(ipsnr[1,:,:,:])
gaussian_4_std_psnr = std(ipsnr[1,:,:,:])
gaussian_4_min_psnr = minimum(ipsnr[1,:,:,:])

print("mean psnr = ", gaussian_4_mean_psnr,"\n")
print("std psnr = ", gaussian_4_std_psnr, "\n")
print("minimum psnr = ", gaussian_4_min_psnr)
# Out:
# mean psnr = 42.41410357762463
# std psnr = 4.987037456162079
# minimum psnr = 36.224043386823574

# %%
gaussian_5_mean_psnr = mean(ipsnr[2,:,:,:])
gaussian_5_std_psnr = std(ipsnr[2,:,:,:])
gaussian_5_min_psnr = minimum(ipsnr[2,:,:,:])

print("mean psnr = ", gaussian_5_mean_psnr,"\n")
print("std psnr = ", gaussian_5_std_psnr, "\n")
print("minimum psnr = ", gaussian_5_min_psnr)
# Out:
# mean psnr = 53.03601003527111
# std psnr = 4.021913128971333
# minimum psnr = 46.95358522620087

# %%
gaussian_6_mean_psnr = mean(ipsnr[3,:,:,:])
gaussian_6_std_psnr = std(ipsnr[3,:,:,:])
gaussian_6_min_psnr = minimum(ipsnr[3,:,:,:])

print("mean psnr = ", gaussian_6_mean_psnr,"\n")
print("std psnr = ", gaussian_6_std_psnr, "\n")
print("minimum psnr = ", gaussian_6_min_psnr)
# Out:
# mean psnr = 59.30268845888608
# std psnr = 3.8060135575188965
# minimum psnr = 48.277102376399895
